# %%
import os

os.getcwd()
# Out:
# '/Users/osahenilawani/DSI_projects/deploying-ai/05_src/assignment_chat'

# %%
from config import MAX_HISTORY

print(MAX_HISTORY)
# Out:
# 10

# %%
MAX_HISTORY = 10

WEATHER_API_KEY = ""
OPENAI_API_KEY = ""

# %%
from dotenv import load_dotenv
from pathlib import Path

load_dotenv(Path(__file__).resolve().parents[1] / ".secrets")

# %%
history
# Out:
# history
